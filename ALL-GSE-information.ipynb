# %%
import os
import asyncio
from playwright.async_api import async_playwright
import requests
from bs4 import BeautifulSoup

GSE_ID = "GSE59867"

# 桌面路径 + 输出文件
BASE = os.path.expanduser("~/Desktop")
FIRST_GSM_FILE = os.path.join(BASE, f"{GSE_ID}_FIRST_GSM.txt")
ALL_GSM_FILE   = os.path.join(BASE, f"{GSE_ID}_ALL_GSM.txt")

print("Single GSM file:", FIRST_GSM_FILE)
print("Merged file:", ALL_GSM_FILE)


# 1. 从 GSE 页面抓所有 GSM
def get_gsm_list(gse_id):
    url = f"https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc={gse_id}"
    html = requests.get(url).text
    soup = BeautifulSoup(html, "html.parser")
    gsm_list = []
    for a in soup.find_all("a"):
        href = a.get("href", "")
        if "acc=GSM" in href:
            gsm = href.split("acc=")[-1]
            if gsm.startswith("GSM"):
                gsm_list.append(gsm)
    return sorted(list(set(gsm_list)))

gsm_ids = get_gsm_list(GSE_ID)
print("Found", len(gsm_ids), "GSM samples")

FIRST_GSM = gsm_ids[0]
print("First GSM:", FIRST_GSM)


# 2. Playwright 抓 GSM 页面
async def fetch_one_gsm(page, gsm):
    url = f"https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc={gsm}"
    await page.goto(url, wait_until="networkidle")
    await page.wait_for_timeout(1500)
    text = await page.inner_text("body")
    return text


# 3. 主流程：生成一个测试 txt + 一个合并 txt
async def main():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        # -------------------------
        # 输出第一个 GSM（测试用）
        # -------------------------
        print("Fetching FIRST GSM:", FIRST_GSM)
        first_text = await fetch_one_gsm(page, FIRST_GSM)
        with open(FIRST_GSM_FILE, "w", encoding="utf-8") as f:
            f.write(first_text)

        # -------------------------
        # 输出全部 GSM 合并 txt
        # -------------------------
        with open(ALL_GSM_FILE, "w", encoding="utf-8") as f:
            for i, gsm in enumerate(gsm_ids, 1):
                print(f"[{i}/{len(gsm_ids)}] Fetching: {gsm}")
                t = await fetch_one_gsm(page, gsm)

                f.write("=" * 80 + "\n")
                f.write(gsm + "\n")
                f.write("=" * 80 + "\n")
                f.write(t)
                f.write("\n\n")

        await browser.close()


await main()
# Out:
# Single GSM file: /Users/wa/Desktop/GSE59867_FIRST_GSM.txt
# Merged file: /Users/wa/Desktop/GSE59867_ALL_GSM.txt
# Found 436 GSM samples
# First GSM: GSM1448335
# Fetching FIRST GSM: GSM1448335
# [1/436] Fetching: GSM1448335
# [2/436] Fetching: GSM1448336
# [3/436] Fetching: GSM1448337
# [4/436] Fetching: GSM1448338
# [5/436] Fetching: GSM1448339
# [6/436] Fetching: GSM1448340
# [7/436] Fetching: GSM1448341
# [8/436] Fetching: GSM1448342
# [9/436] Fetching: GSM1448343
# [10/436] Fetching: GSM1448344
# [11/436] Fetching: GSM1448345
# [12/436] Fetching: GSM1448346
# [13/436] Fetching: GSM1448347
# [14/436] Fetching: GSM1448348
# [15/436] Fetching: GSM1448349
# [16/436] Fetching: GSM1448350
# [17/436] Fetching: GSM1448351
# /Users/wa/anaconda3/envs/py37/lib/python3.7/site-packages/pyee/base.py:152: RuntimeWarning: coroutine 'main' was never awaited
#   funcs = list(self._events.get(event, OrderedDict()).values())
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=Error('Connection closed')>
# playwright._impl._api_types.Error: Connection closed
# [18/436] Fetching: GSM1448352
# [19/436] Fetching: GSM1448353
# [20/436] Fetching: GSM1448354
# [21/436] Fetching: GSM1448355
# [22/436] Fetching: GSM1448356
# [23/436] Fetching: GSM1448357
# [24/436] Fetching: GSM1448358
# [25/436] Fetching: GSM1448359
# [26/436] Fetching: GSM1448360
# [27/436] Fetching: GSM1448361
# [28/436] Fetching: GSM1448362
# [29/436] Fetching: GSM1448363
# [30/436] Fetching: GSM1448364
# [31/436] Fetching: GSM1448365
# [32/436] Fetching: GSM1448366
# [33/436] Fetching: GSM1448367
# [34/436] Fetching: GSM1448368
# [35/436] Fetching: GSM1448369
# [36/436] Fetching: GSM1448370
# [37/436] Fetching: GSM1448371
# [38/436] Fetching: GSM1448372
# [39/436] Fetching: GSM1448373
# [40/436] Fetching: GSM1448374
# [41/436] Fetching: GSM1448375
# [42/436] Fetching: GSM1448376
# [43/436] Fetching: GSM1448377
# [44/436] Fetching: GSM1448378
# [45/436] Fetching: GSM1448379
# [46/436] Fetching: GSM1448380
# [47/436] Fetching: GSM1448381
# [48/436] Fetching: GSM1448382
# [49/436] Fetching: GSM1448383
# [50/436] Fetching: GSM1448384
# [51/436] Fetching: GSM1448385
# [52/436] Fetching: GSM1448386
# [53/436] Fetching: GSM1448387
# [54/436] Fetching: GSM1448388
# [55/436] Fetching: GSM1448389
# [56/436] Fetching: GSM1448390
# [57/436] Fetching: GSM1448391
# [58/436] Fetching: GSM1448392
# [59/436] Fetching: GSM1448393
# [60/436] Fetching: GSM1448394
# [61/436] Fetching: GSM1448395
# [62/436] Fetching: GSM1448396
# [63/436] Fetching: GSM1448397
# [64/436] Fetching: GSM1448398
# [65/436] Fetching: GSM1448399
# [66/436] Fetching: GSM1448400
# [67/436] Fetching: GSM1448401
# [68/436] Fetching: GSM1448402
# [69/436] Fetching: GSM1448403
# [70/436] Fetching: GSM1448404
# [71/436] Fetching: GSM1448405
# [72/436] Fetching: GSM1448406
# [73/436] Fetching: GSM1448407
# [74/436] Fetching: GSM1448408
# [75/436] Fetching: GSM1448409
# [76/436] Fetching: GSM1448410
# [77/436] Fetching: GSM1448411
# [78/436] Fetching: GSM1448412
# [79/436] Fetching: GSM1448413
# [80/436] Fetching: GSM1448414
# [81/436] Fetching: GSM1448415
# [82/436] Fetching: GSM1448416
# [83/436] Fetching: GSM1448417
# [84/436] Fetching: GSM1448418
# [85/436] Fetching: GSM1448419
# [86/436] Fetching: GSM1448420
# [87/436] Fetching: GSM1448421
# [88/436] Fetching: GSM1448422
# [89/436] Fetching: GSM1448423
# [90/436] Fetching: GSM1448424
# [91/436] Fetching: GSM1448425
# [92/436] Fetching: GSM1448426
# [93/436] Fetching: GSM1448427
# [94/436] Fetching: GSM1448428
# [95/436] Fetching: GSM1448429
# [96/436] Fetching: GSM1448430
# [97/436] Fetching: GSM1448431
# [98/436] Fetching: GSM1448432
# [99/436] Fetching: GSM1448433
# [100/436] Fetching: GSM1448434
# [101/436] Fetching: GSM1448435
# [102/436] Fetching: GSM1448436
# [103/436] Fetching: GSM1448437
# [104/436] Fetching: GSM1448438
# [105/436] Fetching: GSM1448439
# [106/436] Fetching: GSM1448440
# [107/436] Fetching: GSM1448441
# [108/436] Fetching: GSM1448442
# [109/436] Fetching: GSM1448443
# [110/436] Fetching: GSM1448444
# [111/436] Fetching: GSM1448445
# [112/436] Fetching: GSM1448446
# [113/436] Fetching: GSM1448447
# [114/436] Fetching: GSM1448448
# [115/436] Fetching: GSM1448449
# [116/436] Fetching: GSM1448450
# [117/436] Fetching: GSM1448451
# [118/436] Fetching: GSM1448452
# [119/436] Fetching: GSM1448453
# [120/436] Fetching: GSM1448454
# [121/436] Fetching: GSM1448455
# [122/436] Fetching: GSM1448456
# [123/436] Fetching: GSM1448457
# [124/436] Fetching: GSM1448458
# [125/436] Fetching: GSM1448459
# [126/436] Fetching: GSM1448460
# [127/436] Fetching: GSM1448461
# [128/436] Fetching: GSM1448462
# [129/436] Fetching: GSM1448463
# [130/436] Fetching: GSM1448464
# [131/436] Fetching: GSM1448465
# [132/436] Fetching: GSM1448466
# [133/436] Fetching: GSM1448467
# [134/436] Fetching: GSM1448468
# [135/436] Fetching: GSM1448469
# [136/436] Fetching: GSM1448470
# [137/436] Fetching: GSM1448471
# [138/436] Fetching: GSM1448472
# [139/436] Fetching: GSM1448473
# [140/436] Fetching: GSM1448474
# [141/436] Fetching: GSM1448475
# [142/436] Fetching: GSM1448476
# [143/436] Fetching: GSM1448477
# [144/436] Fetching: GSM1448478
# [145/436] Fetching: GSM1448479
# [146/436] Fetching: GSM1448480
# [147/436] Fetching: GSM1448481
# [148/436] Fetching: GSM1448482
# [149/436] Fetching: GSM1448483
# [150/436] Fetching: GSM1448484
# [151/436] Fetching: GSM1448485
# [152/436] Fetching: GSM1448486
# [153/436] Fetching: GSM1448487
# [154/436] Fetching: GSM1448488
# [155/436] Fetching: GSM1448489
# [156/436] Fetching: GSM1448490
# [157/436] Fetching: GSM1448491
# [158/436] Fetching: GSM1448492
# [159/436] Fetching: GSM1448493
# [160/436] Fetching: GSM1448494
# [161/436] Fetching: GSM1448495
# [162/436] Fetching: GSM1448496
# [163/436] Fetching: GSM1448497
# [164/436] Fetching: GSM1448498
# [165/436] Fetching: GSM1448499
# [166/436] Fetching: GSM1448500
# [167/436] Fetching: GSM1448501
# [168/436] Fetching: GSM1448502
# [169/436] Fetching: GSM1448503
# [170/436] Fetching: GSM1448504
# [171/436] Fetching: GSM1448505
# [172/436] Fetching: GSM1448506
# [173/436] Fetching: GSM1448507
# [174/436] Fetching: GSM1448508
# [175/436] Fetching: GSM1448509
# [176/436] Fetching: GSM1448510
# [177/436] Fetching: GSM1448511
# [178/436] Fetching: GSM1448512
# [179/436] Fetching: GSM1448513
# [180/436] Fetching: GSM1448514
# [181/436] Fetching: GSM1448515
# [182/436] Fetching: GSM1448516
# [183/436] Fetching: GSM1448517
# [184/436] Fetching: GSM1448518
# [185/436] Fetching: GSM1448519
# [186/436] Fetching: GSM1448520
# [187/436] Fetching: GSM1448521
# [188/436] Fetching: GSM1448522
# [189/436] Fetching: GSM1448523
# [190/436] Fetching: GSM1448524
# [191/436] Fetching: GSM1448525
# [192/436] Fetching: GSM1448526
# [193/436] Fetching: GSM1448527
# [194/436] Fetching: GSM1448528
# [195/436] Fetching: GSM1448529
# [196/436] Fetching: GSM1448530
# [197/436] Fetching: GSM1448531
# [198/436] Fetching: GSM1448532
# [199/436] Fetching: GSM1448533
# [200/436] Fetching: GSM1448534
# [201/436] Fetching: GSM1448535
# [202/436] Fetching: GSM1448536
# [203/436] Fetching: GSM1448537
# [204/436] Fetching: GSM1448538
# [205/436] Fetching: GSM1448539
# [206/436] Fetching: GSM1448540
# [207/436] Fetching: GSM1448541
# [208/436] Fetching: GSM1448542
# [209/436] Fetching: GSM1448543
# [210/436] Fetching: GSM1448544
# [211/436] Fetching: GSM1448545
# [212/436] Fetching: GSM1448546
# [213/436] Fetching: GSM1448547
# [214/436] Fetching: GSM1448548
# [215/436] Fetching: GSM1448549
# [216/436] Fetching: GSM1448550
# [217/436] Fetching: GSM1448551
# [218/436] Fetching: GSM1448552
# [219/436] Fetching: GSM1448553
# [220/436] Fetching: GSM1448554
# [221/436] Fetching: GSM1448555
# [222/436] Fetching: GSM1448556
# [223/436] Fetching: GSM1448557
# [224/436] Fetching: GSM1448558
# [225/436] Fetching: GSM1448559
# [226/436] Fetching: GSM1448560
# [227/436] Fetching: GSM1448561
# [228/436] Fetching: GSM1448562
# [229/436] Fetching: GSM1448563
# [230/436] Fetching: GSM1448564
# [231/436] Fetching: GSM1448565
# [232/436] Fetching: GSM1448566
# [233/436] Fetching: GSM1448567
# [234/436] Fetching: GSM1448568
# [235/436] Fetching: GSM1448569
# [236/436] Fetching: GSM1448570
# [237/436] Fetching: GSM1448571
# [238/436] Fetching: GSM1448572
# [239/436] Fetching: GSM1448573
# [240/436] Fetching: GSM1448574
# [241/436] Fetching: GSM1448575
# [242/436] Fetching: GSM1448576
# [243/436] Fetching: GSM1448577
# [244/436] Fetching: GSM1448578
# [245/436] Fetching: GSM1448579
# [246/436] Fetching: GSM1448580
# [247/436] Fetching: GSM1448581
# [248/436] Fetching: GSM1448582
# [249/436] Fetching: GSM1448583
# [250/436] Fetching: GSM1448584
# [251/436] Fetching: GSM1448585
# [252/436] Fetching: GSM1448586
# [253/436] Fetching: GSM1448587
# [254/436] Fetching: GSM1448588
# [255/436] Fetching: GSM1448589
# [256/436] Fetching: GSM1448590
# [257/436] Fetching: GSM1448591
# [258/436] Fetching: GSM1448592
# [259/436] Fetching: GSM1448593
# [260/436] Fetching: GSM1448594
# [261/436] Fetching: GSM1448595
# [262/436] Fetching: GSM1448596
# [263/436] Fetching: GSM1448597
# [264/436] Fetching: GSM1448598
# [265/436] Fetching: GSM1448599
# [266/436] Fetching: GSM1448600
# [267/436] Fetching: GSM1448601
# [268/436] Fetching: GSM1448602
# [269/436] Fetching: GSM1448603
# [270/436] Fetching: GSM1448604
# [271/436] Fetching: GSM1448605
# [272/436] Fetching: GSM1448606
# [273/436] Fetching: GSM1448607
# [274/436] Fetching: GSM1448608
# [275/436] Fetching: GSM1448609
# [276/436] Fetching: GSM1448610
# [277/436] Fetching: GSM1448611
# [278/436] Fetching: GSM1448612
# [279/436] Fetching: GSM1448613
# [280/436] Fetching: GSM1448614
# [281/436] Fetching: GSM1448615
# [282/436] Fetching: GSM1448616
# [283/436] Fetching: GSM1448617
# [284/436] Fetching: GSM1448618
# [285/436] Fetching: GSM1448619
# [286/436] Fetching: GSM1448620
# [287/436] Fetching: GSM1448621
# [288/436] Fetching: GSM1448622
# [289/436] Fetching: GSM1448623
# [290/436] Fetching: GSM1448624
# [291/436] Fetching: GSM1448625
# [292/436] Fetching: GSM1448626
# [293/436] Fetching: GSM1448627
# [294/436] Fetching: GSM1448628
# [295/436] Fetching: GSM1448629
# [296/436] Fetching: GSM1448630
# [297/436] Fetching: GSM1448631
# [298/436] Fetching: GSM1448632
# [299/436] Fetching: GSM1448633
# [300/436] Fetching: GSM1448634
# [301/436] Fetching: GSM1448635
# [302/436] Fetching: GSM1448636
# [303/436] Fetching: GSM1448637
# [304/436] Fetching: GSM1448638
# [305/436] Fetching: GSM1448639
# [306/436] Fetching: GSM1448640
# [307/436] Fetching: GSM1448641
# [308/436] Fetching: GSM1448642
# [309/436] Fetching: GSM1448643
# [310/436] Fetching: GSM1448644
# [311/436] Fetching: GSM1448645
# [312/436] Fetching: GSM1448646
# [313/436] Fetching: GSM1448647
# [314/436] Fetching: GSM1448648
# [315/436] Fetching: GSM1448649
# [316/436] Fetching: GSM1448650
# [317/436] Fetching: GSM1448651
# [318/436] Fetching: GSM1448652
# [319/436] Fetching: GSM1448653
# [320/436] Fetching: GSM1448654
# [321/436] Fetching: GSM1448655
# [322/436] Fetching: GSM1448656
# [323/436] Fetching: GSM1448657
# [324/436] Fetching: GSM1448658
# [325/436] Fetching: GSM1448659
# [326/436] Fetching: GSM1448660
# [327/436] Fetching: GSM1448661
# [328/436] Fetching: GSM1448662
# [329/436] Fetching: GSM1448663
# [330/436] Fetching: GSM1448664
# [331/436] Fetching: GSM1448665
# [332/436] Fetching: GSM1448666
# [333/436] Fetching: GSM1448667
# [334/436] Fetching: GSM1448668
# [335/436] Fetching: GSM1448669
# [336/436] Fetching: GSM1448670
# [337/436] Fetching: GSM1448671
# [338/436] Fetching: GSM1448672
# [339/436] Fetching: GSM1448673
# [340/436] Fetching: GSM1448674
# [341/436] Fetching: GSM1448675
# [342/436] Fetching: GSM1448676
# [343/436] Fetching: GSM1448677
# [344/436] Fetching: GSM1448678
# [345/436] Fetching: GSM1448679
# [346/436] Fetching: GSM1448680
# [347/436] Fetching: GSM1448681
# [348/436] Fetching: GSM1448682
# [349/436] Fetching: GSM1448683
# [350/436] Fetching: GSM1448684
# [351/436] Fetching: GSM1448685
# [352/436] Fetching: GSM1448686
# [353/436] Fetching: GSM1448687
# [354/436] Fetching: GSM1448688
# [355/436] Fetching: GSM1448689
# [356/436] Fetching: GSM1448690
# [357/436] Fetching: GSM1448691
# [358/436] Fetching: GSM1448692
# [359/436] Fetching: GSM1448693
# [360/436] Fetching: GSM1448694
# [361/436] Fetching: GSM1448695
# [362/436] Fetching: GSM1448696
# [363/436] Fetching: GSM1448697
# [364/436] Fetching: GSM1448698
# [365/436] Fetching: GSM1448699
# [366/436] Fetching: GSM1448700
# [367/436] Fetching: GSM1448701
# [368/436] Fetching: GSM1448702
# [369/436] Fetching: GSM1448703
# [370/436] Fetching: GSM1448704
# [371/436] Fetching: GSM1448705
# [372/436] Fetching: GSM1448706
# [373/436] Fetching: GSM1448707
# [374/436] Fetching: GSM1448708
# [375/436] Fetching: GSM1448709
# [376/436] Fetching: GSM1448710
# [377/436] Fetching: GSM1448711
# [378/436] Fetching: GSM1448712
# [379/436] Fetching: GSM1448713
# [380/436] Fetching: GSM1448714
# [381/436] Fetching: GSM1448715
# [382/436] Fetching: GSM1448716
# [383/436] Fetching: GSM1448717
# [384/436] Fetching: GSM1448718
# [385/436] Fetching: GSM1448719
# [386/436] Fetching: GSM1448720
# [387/436] Fetching: GSM1448721
# [388/436] Fetching: GSM1448722
# [389/436] Fetching: GSM1448723
# [390/436] Fetching: GSM1448724
# [391/436] Fetching: GSM1620759
# [392/436] Fetching: GSM1620760
# [393/436] Fetching: GSM1620761
# [394/436] Fetching: GSM1620762
# [395/436] Fetching: GSM1620763
# [396/436] Fetching: GSM1620764
# [397/436] Fetching: GSM1620765
# [398/436] Fetching: GSM1620766
# [399/436] Fetching: GSM1620767
# [400/436] Fetching: GSM1620768
# [401/436] Fetching: GSM1620769
# [402/436] Fetching: GSM1620770
# [403/436] Fetching: GSM1620771
# [404/436] Fetching: GSM1620772
# [405/436] Fetching: GSM1620773
# [406/436] Fetching: GSM1620774
# [407/436] Fetching: GSM1620775
# [408/436] Fetching: GSM1620776
# [409/436] Fetching: GSM1620777
# [410/436] Fetching: GSM1620778
# [411/436] Fetching: GSM1620779
# [412/436] Fetching: GSM1620780
# [413/436] Fetching: GSM1620781
# [414/436] Fetching: GSM1620782
# [415/436] Fetching: GSM1620783
# [416/436] Fetching: GSM1620784
# [417/436] Fetching: GSM1620785
# [418/436] Fetching: GSM1620786
# [419/436] Fetching: GSM1620787
# [420/436] Fetching: GSM1620788
# [421/436] Fetching: GSM1620789
# [422/436] Fetching: GSM1620790
# [423/436] Fetching: GSM1620791
# [424/436] Fetching: GSM1620792
# [425/436] Fetching: GSM1620793
# [426/436] Fetching: GSM1620794
# [427/436] Fetching: GSM1620795
# [428/436] Fetching: GSM1620796
# [429/436] Fetching: GSM1620797
# [430/436] Fetching: GSM1620798
# [431/436] Fetching: GSM1620799
# [432/436] Fetching: GSM1620800
# [433/436] Fetching: GSM1620801
# [434/436] Fetching: GSM1620802
# [435/436] Fetching: GSM1620803
# [436/436] Fetching: GSM1620804
